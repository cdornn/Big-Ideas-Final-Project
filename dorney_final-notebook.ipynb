# %% [markdown]
# # Final Project Individual Notebook
# ----

# %% [markdown]
# My group has chosen to rank the best neighborhood in Pittsburgh based on the amount of police activity. I am using a dataset that, according to the source of the data itself, "contains crime incident data after it has been validated and processed to meet Uniform Crime Reporting (UCR) standards." Therefore, this dataset shows how often police have to interfere where and what they needed to take care of at the time.

# %% [markdown]
# ## My Code:

# %%
# Neighborhood Graph

import pandas as pd
import matplotlib.pyplot as plt

# read in incidents.csv
incidents = pd.read_csv("https://data.wprdc.org/dataset/5e6711a3-90e5-457d-8c73-445fb5f363e2/resource/391942e2-25ef-43e4-8263-f8519fa8aada/download/archive-police-blotter.csv",low_memory=False)

plt.figure(figsize=(70, 100)) 
incidents["INCIDENTNEIGHBORHOOD"].value_counts().plot(kind='bar', color="#1c2a8a", width=0.9)

plt.title("# Of Recorded Police Incidents Across Pittsburgh Neighborhoods", fontsize = 45)

plt.xticks(fontsize = 25, rotation = "vertical")
plt.yticks(fontsize = 45)

plt.xlabel("Neighborhood Name", fontsize = 50)
plt.ylabel("Number of Incidents", fontsize = 50)

# Display graph 
plt.show()

# %%
import pandas as pd

# read in incidents.csv

incidents = pd.read_csv("https://data.wprdc.org/dataset/5e6711a3-90e5-457d-8c73-445fb5f363e2/resource/391942e2-25ef-43e4-8263-f8519fa8aada/download/archive-police-blotter.csv", low_memory=False)

# Show the counts, now in words/Values shown in ascending order so we can see the one with the least incidents reported
# Disregard Outside County and Outside State, as they are NOT part of Pittsburgh, making it Mt. Oliver BORO (not to be confused with the many others)

incidents['INCIDENTNEIGHBORHOOD'].value_counts(ascending=True)
# Out:
# Outside County                   201
# Outside State                    202
# Mt. Oliver Boro                  239
# Chartiers City                   427
# New Homestead                    459
#                                ...
# Shadyside                      14584
# Bloomfield                     16223
# Carrick                        18059
# South Side Flats               28251
# Golden Triangle/Civic Arena    29147
# Name: INCIDENTNEIGHBORHOOD, Length: 94, dtype: int64

# %% [markdown]
# ## Conclusion:
#
# From my own personal findings, even though the neighborhood that is accredited to having the least amount of incidents is "Outside County," this is *not* actually in Pittsburgh and simply a marker used by the Pittsburgh police to say that this was, well, an incident reported in a county outside Pittsburgh. So, with this in mind, based on the graph and the display of value_counts() for each neighborhood, it can be assumed that "Mt. Oliver Boro" is the best, due to it having the least amount of reported incidents at 239. This Mt. Oliver is not to be confused with Mt. Oliver (no Boro in the name), as there are **two**  Mt. Olivers in Pittsburgh. So in conclusion, based on both my visual and textual findings, Mt. Oliver Boro is the best neighborhood in Pittsburgh, due to it having the least overall reported incidents by the police.
#
# Based on what I have collected here, the worst neighborhood, although we were not looking for it seemed to be "Golden Triangle/Civic Arena." So if its any neighborhood to *avoid* its clearly that one with 29147 reported incidents, ***yikes***.
